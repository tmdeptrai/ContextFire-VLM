# %%
from transformers import AutoProcessor, AutoModelForImageTextToText, BitsAndBytesConfig
import torch

torch_device = "cuda"
model_checkpoint = "OpenGVLab/InternVL3-2B-hf"
processor = AutoProcessor.from_pretrained(model_checkpoint)
model = AutoModelForImageTextToText.from_pretrained(model_checkpoint, device_map=torch_device, torch_dtype=torch.bfloat16)
print("Successfully loaded the model")
# Out:
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# Successfully loaded the model

# %%
adapter_path = "internvl3-2B-finetune"
model.load_adapter(adapter_path)

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "url": "https://huggingface.co/datasets/merve/vlm_test_images/resolve/main/throughput_smolvlm.png"},
                {"type": "text", "text": "\nWhat is this chart about?"},
            ],
        },
    ]

# %%
def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    inputs = processor.apply_chat_template(
        sample,
        padding=True,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    ).to(model.device, dtype=torch.bfloat16)

    generated_ids = model.generate(**inputs, max_new_tokens=1024,pad_token_id=151645)

    trimmed_generated_ids = [out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)]

    output_text = processor.batch_decode(
        trimmed_generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )

    return output_text[0]

generate_text_from_sample(model,processor,messages)
# Out:
# 'This chart compares the throughput of different models for processing image and text inputs with batch size set to 1 on an H100 GPU. The throughput is measured in tokens per second. The chart is divided into two sections: one for SmolVLM (Ours) and the other for Qwen2-VL-2B.\n\n- **SmolVLM (Ours)**:\n  - **Prefill**: 17,792.75 tokens per second\n  - **Prefill with 2 images**: 23,573.10 tokens per second\n\n- **Qwen2-VL-2B**:\n  - **Generation**: 5,405.81 tokens per second\n  - **Generation with 2 images**: 5,302.34 tokens per second\n\n- **SmolVLM (Ours)**:\n  - **Generation**: 35.93 tokens per second\n  - **Generation with 2 images**: 28.79 tokens per second\n\n- **Qwen2-VL-2B**:\n  - **Generation**: 4.80 tokens per second\n  - **Generation with 2 images**: 1.82 tokens per second\n\nThe chart highlights that SmolVLM (Ours) outperforms Qwen2-VL-2B in terms of throughput for both prefill and generation tasks with and without images, especially in the prefill with 2 images scenario.'

# %% [markdown]
# # Alright, let's test

# %%
# Load ground truth data
import pandas as pd
df = pd.read_csv('FIRENET.csv')
df.head(10)
# Out:
#                   image_path            label  \
# 0   FIRENET/train/image1.jpg   dangerous fire
# 1   FIRENET/train/image2.jpg   dangerous fire
# 2   FIRENET/train/image3.jpg  controlled fire
# 3   FIRENET/train/image4.jpg  controlled fire
# 4   FIRENET/train/image5.jpg   dangerous fire
# 5   FIRENET/train/image6.jpg  controlled fire
# 6   FIRENET/train/image7.jpg  controlled fire
# 7   FIRENET/train/image8.jpg   dangerous fire
# 8   FIRENET/train/image9.jpg   dangerous fire
# 9  FIRENET/train/image10.jpg  controlled fire
#
#                                              caption
# 0  The image shows a car engulfed in flames on a ...
# 1  The image shows a scene of a fire on the side ...
# 2  A person holding a lit cigarette with smoke ri...
# 3  The image shows a single cupcake with pink fro...
# 4  A car is engulfed in flames on a street, with ...
# 5  A person holding a lit cigarette in a dimly li...
# 6  The image shows two lit candles, one yellow an...
# 7  A race car on fire with flames and smoke billo...
# 8  The image shows a scene with a car on fire in ...
# 9  Two individuals in school uniforms are standin...

# %%
from PIL import Image
import json

system_message = """You are a Vision Language Model specialized in detecting clues of fire, smoke and surrounding context then classify them as no fire, dangerous fire or controlled fire.
Your task is to analyze the provided image and respond to queries with concise answers, usually a json format of a caption and a label.
Summarize what you see in the image. Describe the environment, key objects, people, and any signs of fire or smoke.
Based on your summary, classify the fire situation: no fire(e.g., fire alarm, fire distinguisher,..), controlled fire (e.g., fireplace emitting, campfire, cooking, candles, match stick, lighter..) or a dangerous/uncontrolled fire (e.g., curtains on fire, smoke on ceiling, couch on fire, bed sheet on fire, spreading fire on furniture..)
Focus on delivering accurate, succinct caption and precise label based on the visual information. Add a brief explanation for your choice of label in the caption if necessary."""

user_query = """Summarize this situation in the image, look for signs of fire and smoke and classify whether the situation is: \n
- **No fire**: The image may contain symbols, representations, or objects related to fire, but no actual fire or smoke is present. This includes things like warning signs, fire safety equipment (extinguishers, alarms), digital or printed representations of fire (e.g., a laptop screen showing fire, a drawing or painting), or thematic decorations.\n
- **Controlled fire**: There is a visible flame or heat source, but it is clearly contained, expected, and managed by people or objects in its environment. This includes fireplaces, campfires, cooking appliances, candles, lighters, or matchsticks. There should be no signs of danger, spread, panic, or damage in the surroundings.\n
- **Dangerous (uncontrolled) fire**: The fire appears out of control or harmful to the environment or people. Signs include flames spreading to flammable materials (e.g., curtains, furniture, bedding), thick smoke near the ceiling, charring, visible structural damage, or people reacting with fear or urgency. The context suggests potential or ongoing property damage or bodily harm.\n
Add a brief explanation for your choice of label in the caption if necessary.\n
Respond only this json format:\n
{ \"caption\": \"...\", \"label\": \"no fire\"|\"controlled fire\"|\"dangerous fire\" }
"""

def format_data(sample):
    return [
        {
            "role": "system",
            "content": [{"type": "text", "text": system_message}],
        },
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "path": f"{sample['image_path']}",
                },
                {
                    "type": "text",
                    "text": "\n"+user_query,
                },
            ],
        },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": f"""```json\n{json.dumps({"caption": sample["caption"], "label": sample["label"]}, ensure_ascii=False)}\n```"""
                }
            ],
        },
    ]

# %%
import time, re, json
device = "cuda"

def process_sample(sample):
    """Process a single image and return the model's prediction, caption and inference time"""
    try:
        # Start timing
        start_time = time.time()
        
        clean_output = generate_text_from_sample(model, processor, sample)
        
        # Match the last complete JSON block
        matches = re.findall(r'\{[^{}]+\}', clean_output, re.DOTALL)
        if matches:
            try:
                result = json.loads(matches[-1])  # take the last match (most likely correct)
                caption = result.get("caption", "").strip()
                label = result.get("label", "").strip()
            except Exception as e:
                print(f"❌ Failed to parse JSON for {sample["image_path"]}: {e}")
                caption = clean_output
                label = "unknown"
        else:
            print(f"❌ No JSON block found in output for {sample["image_path"]}")
            caption = clean_output
            label = "unknown"

        # Calculate inference time
        inference_time = time.time() - start_time
        
        return label, caption, inference_time
            
    except Exception as e:
        # print(f"Error processing {sample["image_path"]}: {str(e)}")
        return "error", "", 0.0

# %%
import os
import numpy as np
# Process all images and collect predictions
predictions = []
captions = []
inference_times = []
ground_truth = []

for idx, row in df.iterrows():
    print(f"processing {row["image_path"]}")
    sample = format_data(row)
    pred, caption, inf_time = process_sample(sample)
    predictions.append(pred)
    captions.append(caption)
    inference_times.append(inf_time)
    ground_truth.append(row['label'])
    if idx % 10 == 0:
        print(f"Processed {idx} images... Average inference time so far: {np.mean(inference_times):.3f}s")

print(f"\nProcessing complete! Average inference time: {np.mean(inference_times):.3f}s")
# Out:
# processing FIRENET/train/image1.jpg
# Processed 0 images... Average inference time so far: 1.902s
# processing FIRENET/train/image2.jpg
# processing FIRENET/train/image3.jpg
# processing FIRENET/train/image4.jpg
# processing FIRENET/train/image5.jpg
# processing FIRENET/train/image6.jpg
# processing FIRENET/train/image7.jpg
# processing FIRENET/train/image8.jpg
# processing FIRENET/train/image9.jpg
# processing FIRENET/train/image10.jpg
# processing FIRENET/train/image11.jpg
# Processed 10 images... Average inference time so far: 1.845s
# processing FIRENET/train/image12.jpg
# processing FIRENET/train/image13.jpg
# processing FIRENET/train/image14.jpg
# processing FIRENET/train/image15.jpg
# processing FIRENET/train/image16.jpg
# processing FIRENET/train/image17.jpg
# processing FIRENET/train/image18.jpg
# processing FIRENET/train/image19.jpg
# processing FIRENET/train/image20.jpg
# processing FIRENET/train/image21.jpg
# Processed 20 images... Average inference time so far: 1.890s
# processing FIRENET/train/image22.jpg
# processing FIRENET/train/image23.jpg
# processing FIRENET/train/image24.jpg
# processing FIRENET/train/image25.jpg
# processing FIRENET/train/image26.jpg
# processing FIRENET/train/image27.jpg
# processing FIRENET/train/image28.jpg
# processing FIRENET/train/image29.jpg
# processing FIRENET/train/image30.jpg
# processing FIRENET/train/image31.jpg
# Processed 30 images... Average inference time so far: 1.937s
# processing FIRENET/train/image32.jpg
# processing FIRENET/train/image33.jpg
# processing FIRENET/train/image34.jpg
# processing FIRENET/train/image35.jpg
# processing FIRENET/train/image36.jpg
# processing FIRENET/train/image37.jpg
# processing FIRENET/train/image38.jpg
# processing FIRENET/train/image39.jpg
# processing FIRENET/train/image40.jpg
# processing FIRENET/train/image41.jpg
# Processed 40 images... Average inference time so far: 1.965s
# processing FIRENET/train/image42.jpg
# processing FIRENET/train/image43.jpg
# processing FIRENET/train/image44.jpg
# processing FIRENET/train/image45.jpg
# processing FIRENET/train/image46.jpg
# processing FIRENET/train/image47.jpg
# processing FIRENET/train/image48.jpg
# processing FIRENET/train/image49.jpg
# processing FIRENET/train/image50.jpg
# processing FIRENET/train/image51.jpg
# Processed 50 images... Average inference time so far: 1.925s
# processing FIRENET/train/image52.jpg
# processing FIRENET/train/image53.jpg
# processing FIRENET/train/image54.jpg
# processing FIRENET/train/image55.jpg
# processing FIRENET/train/image56.jpg
# processing FIRENET/train/image57.jpg
# processing FIRENET/train/image58.jpg
# processing FIRENET/train/image59.jpg
# processing FIRENET/train/image60.jpg
# processing FIRENET/train/image61.jpg
# Processed 60 images... Average inference time so far: 1.884s
# processing FIRENET/train/image62.jpg
# processing FIRENET/train/image63.jpg
# processing FIRENET/train/image64.jpg
# processing FIRENET/train/image65.jpg
# processing FIRENET/train/image66.jpg
# processing FIRENET/train/image67.jpg
# processing FIRENET/train/image68.jpg
# processing FIRENET/train/image69.jpg
# processing FIRENET/train/image70.jpg
# processing FIRENET/train/image71.jpg
# Processed 70 images... Average inference time so far: 1.866s
# processing FIRENET/train/image72.jpg
# processing FIRENET/train/image73.jpg
# processing FIRENET/train/image74.jpg
# processing FIRENET/train/image75.jpg
# processing FIRENET/train/image76.jpg
# processing FIRENET/train/image77.jpg
# processing FIRENET/train/image78.jpg
# processing FIRENET/train/image79.jpg
# processing FIRENET/train/image80.jpg
# processing FIRENET/train/image81.jpg
# Processed 80 images... Average inference time so far: 1.873s
# processing FIRENET/train/image82.jpg
# processing FIRENET/train/image83.jpg
# processing FIRENET/train/image84.jpg
# processing FIRENET/train/image85.jpg
# processing FIRENET/train/image86.jpg
# processing FIRENET/train/image87.jpg
# processing FIRENET/train/image88.jpg
# processing FIRENET/train/image89.jpg
# processing FIRENET/train/image90.jpg
# processing FIRENET/train/image91.jpg
# Processed 90 images... Average inference time so far: 1.896s
# processing FIRENET/train/image92.jpg
# processing FIRENET/train/image93.jpg
# processing FIRENET/train/image94.jpg
# processing FIRENET/train/image95.jpg
# processing FIRENET/train/image96.jpg
# processing FIRENET/train/image97.jpg
# processing FIRENET/train/image98.jpg
# processing FIRENET/train/image99.jpg
# processing FIRENET/train/image100.jpg
# processing FIRENET/train/image101.jpg
# Processed 100 images... Average inference time so far: 1.867s
# processing FIRENET/train/image102.jpg
# processing FIRENET/train/image103.jpg
# processing FIRENET/train/image104.jpg
# processing FIRENET/train/image105.jpg
# processing FIRENET/train/image106.jpg
# processing FIRENET/train/image107.jpg
# processing FIRENET/train/image108.jpg
# processing FIRENET/train/image109.jpg
# processing FIRENET/train/image110.jpg
# processing FIRENET/train/image111.jpg
# Processed 110 images... Average inference time so far: 1.865s
# processing FIRENET/train/image112.jpg
# processing FIRENET/train/image113.jpg
# processing FIRENET/train/image114.jpg
# processing FIRENET/train/image115.jpg
# processing FIRENET/train/image116.jpg
# processing FIRENET/train/image117.jpg
# processing FIRENET/train/image118.jpg
# processing FIRENET/train/image119.jpg
# processing FIRENET/train/image120.jpg
# processing FIRENET/train/image121.jpg
# Processed 120 images... Average inference time so far: 1.864s
# processing FIRENET/train/image122.jpg
# processing FIRENET/train/image123.jpg
# processing FIRENET/train/image124.jpg
# processing FIRENET/train/image125.jpg
# processing FIRENET/train/image126.jpg
# processing FIRENET/train/image127.jpg
# processing FIRENET/train/image128.jpg
# processing FIRENET/train/image129.jpg
# processing FIRENET/train/image130.jpg
# processing FIRENET/train/image131.jpg
# Processed 130 images... Average inference time so far: 1.880s
# processing FIRENET/train/image132.jpg
# processing FIRENET/train/image133.jpg
# processing FIRENET/train/image134.jpg
# processing FIRENET/train/image135.jpg
# processing FIRENET/train/image136.jpg
# processing FIRENET/train/image137.jpg
# processing FIRENET/train/image138.jpg
# processing FIRENET/train/image139.jpg
# processing FIRENET/train/image140.jpg
# processing FIRENET/train/image141.jpg
# Processed 140 images... Average inference time so far: 1.876s
# processing FIRENET/train/image142.jpg
# processing FIRENET/train/image143.jpg
# processing FIRENET/train/image144.jpg
# processing FIRENET/train/image145.jpg
# processing FIRENET/train/image146.jpg
# processing FIRENET/train/image147.jpg
# processing FIRENET/train/image148.jpg
# processing FIRENET/train/image149.jpg
# processing FIRENET/train/image150.jpg
# processing FIRENET/train/image151.jpg
# Processed 150 images... Average inference time so far: 1.868s
# processing FIRENET/train/image152.jpg
# processing FIRENET/train/image153.jpg
# processing FIRENET/train/image154.jpg
# processing FIRENET/train/image155.jpg
# processing FIRENET/train/image156.jpg
# processing FIRENET/train/image157.jpg
# processing FIRENET/train/image158.jpg
# processing FIRENET/train/image159.jpg
# processing FIRENET/train/image160.jpg
# processing FIRENET/train/image161.jpg
# Processed 160 images... Average inference time so far: 1.869s
# processing FIRENET/train/image162.jpg
# processing FIRENET/train/image163.jpg
# processing FIRENET/train/image164.jpg
# processing FIRENET/train/image165.jpg
# processing FIRENET/train/image166.jpg
# processing FIRENET/train/image167.jpg
# processing FIRENET/train/image168.jpg
# processing FIRENET/train/image169.jpg
# processing FIRENET/train/image170.jpg
# processing FIRENET/train/image171.jpg
# Processed 170 images... Average inference time so far: 1.862s
# processing FIRENET/train/image172.jpg
# processing FIRENET/train/image173.jpg
# processing FIRENET/train/image174.jpg
# processing FIRENET/train/image175.jpg
# processing FIRENET/train/image176.jpg
# processing FIRENET/train/image177.jpg
# processing FIRENET/train/image178.jpg
# processing FIRENET/train/image179.jpg
# processing FIRENET/train/image180.jpg
# processing FIRENET/train/image181.jpg
# Processed 180 images... Average inference time so far: 1.861s
# processing FIRENET/train/image182.jpg
# processing FIRENET/train/image183.jpg
# processing FIRENET/train/image184.jpg
# processing FIRENET/train/image185.jpg
# processing FIRENET/train/image186.jpg
# processing FIRENET/train/image187.jpg
# processing FIRENET/train/image188.jpg
# processing FIRENET/train/image189.jpg
# processing FIRENET/train/image190.jpg
# processing FIRENET/train/image191.jpg
# Processed 190 images... Average inference time so far: 1.858s
# processing FIRENET/train/image192.jpg
# processing FIRENET/train/image193.jpg
# processing FIRENET/train/image194.jpg
# processing FIRENET/train/image195.jpg
# processing FIRENET/train/image196.jpg
# processing FIRENET/train/image197.jpg
# processing FIRENET/train/image198.jpg
# processing FIRENET/train/image199.jpg
# processing FIRENET/train/image200.jpg
# processing FIRENET/train/image201.jpg
# Processed 200 images... Average inference time so far: 1.858s
# processing FIRENET/train/image202.jpg
# processing FIRENET/train/image203.jpg
# processing FIRENET/train/image204.jpg
# processing FIRENET/train/image205.jpg
# processing FIRENET/train/image206.jpg
# processing FIRENET/train/image207.jpg
# processing FIRENET/train/image208.jpg
# processing FIRENET/train/image209.jpg
# processing FIRENET/train/image210.jpg
# processing FIRENET/train/image211.jpg
# Processed 210 images... Average inference time so far: 1.863s
# processing FIRENET/train/image212.jpg
# processing FIRENET/train/image213.jpg
# processing FIRENET/train/image214.jpg
# processing FIRENET/train/image215.jpg
# processing FIRENET/train/image216.jpg
# processing FIRENET/train/image217.jpg
# processing FIRENET/train/image218.jpg
# processing FIRENET/train/image219.jpg
# processing FIRENET/train/image220.jpg
# processing FIRENET/train/image221.jpg
# Processed 220 images... Average inference time so far: 1.861s
# processing FIRENET/train/image222.jpg
# processing FIRENET/train/image223.jpg
# processing FIRENET/train/image224.jpg
# processing FIRENET/train/image225.jpg
# processing FIRENET/train/image226.jpg
# processing FIRENET/train/image227.jpg
# processing FIRENET/train/image228.jpg
# processing FIRENET/train/image229.jpg
# processing FIRENET/train/image230.jpg
# processing FIRENET/train/image231.jpg
# Processed 230 images... Average inference time so far: 1.853s
# processing FIRENET/train/image232.jpg
# processing FIRENET/train/image233.jpg
# processing FIRENET/train/image234.jpg
# processing FIRENET/train/image235.jpg
# processing FIRENET/train/image236.jpg
# processing FIRENET/train/image237.jpg
# processing FIRENET/train/image238.jpg
# processing FIRENET/train/image239.jpg
# processing FIRENET/train/image240.jpg
# processing FIRENET/train/image241.jpg
# Processed 240 images... Average inference time so far: 1.852s
# processing FIRENET/train/image242.jpg
# processing FIRENET/train/image243.jpg
# processing FIRENET/train/image244.jpg
# processing FIRENET/train/image245.jpg
# processing FIRENET/train/image246.jpg
# processing FIRENET/train/image247.jpg
# processing FIRENET/train/image248.jpg
# processing FIRENET/train/image249.jpg
# processing FIRENET/train/image250.jpg
# processing FIRENET/train/image251.jpg
# Processed 250 images... Average inference time so far: 1.859s
# processing FIRENET/train/image252.jpg
# processing FIRENET/train/image253.jpg
# processing FIRENET/train/image254.jpg
# processing FIRENET/train/image255.jpg
# processing FIRENET/train/image256.jpg
# processing FIRENET/train/image257.jpg
# processing FIRENET/train/image258.jpg
# processing FIRENET/train/image259.jpg
# processing FIRENET/train/image260.jpg
# processing FIRENET/train/image261.jpg
# Processed 260 images... Average inference time so far: 1.858s
# processing FIRENET/train/image262.jpg
# processing FIRENET/train/image263.jpg
# processing FIRENET/train/image264.jpg
# processing FIRENET/train/image265.jpg
# processing FIRENET/train/image266.jpg
# processing FIRENET/train/image267.jpg
# processing FIRENET/train/image268.jpg
# processing FIRENET/train/image269.jpg
# processing FIRENET/train/image270.jpg
# processing FIRENET/train/image271.jpg
# Processed 270 images... Average inference time so far: 1.859s
# processing FIRENET/train/image272.jpg
# processing FIRENET/train/image273.jpg
# processing FIRENET/train/image274.jpg
# processing FIRENET/train/image275.jpg
# processing FIRENET/train/image276.jpg
# processing FIRENET/train/image277.jpg
# processing FIRENET/train/image278.jpg
# processing FIRENET/train/image279.jpg
# processing FIRENET/train/image280.jpg
# processing FIRENET/train/image281.jpg
# Processed 280 images... Average inference time so far: 1.861s
# processing FIRENET/train/image282.jpg
# processing FIRENET/train/image283.jpg
# processing FIRENET/train/image284.jpg
# processing FIRENET/train/image285.jpg
# processing FIRENET/train/image286.jpg
# processing FIRENET/train/image287.jpg
# processing FIRENET/train/image288.jpg
# processing FIRENET/train/image289.jpg
# processing FIRENET/train/image290.jpg
# processing FIRENET/train/image291.jpg
# Processed 290 images... Average inference time so far: 1.870s
# processing FIRENET/train/image292.jpg
# processing FIRENET/train/image293.jpg
# processing FIRENET/train/image294.jpg
# processing FIRENET/train/image295.jpg
# processing FIRENET/train/image296.jpg
# processing FIRENET/train/image297.jpg
# processing FIRENET/train/image298.jpg
# processing FIRENET/train/image299.jpg
# processing FIRENET/train/image300.jpg
# processing FIRENET/train/image301.jpg
# Processed 300 images... Average inference time so far: 1.873s
# processing FIRENET/train/image302.jpg
# processing FIRENET/train/image303.jpg
# processing FIRENET/train/image304.jpg
# processing FIRENET/train/image305.jpg
# processing FIRENET/train/image306.jpg
# processing FIRENET/train/image307.jpg
# processing FIRENET/train/image308.jpg
# processing FIRENET/train/image309.jpg
# processing FIRENET/train/image310.jpg
# processing FIRENET/train/image311.jpg
# Processed 310 images... Average inference time so far: 1.880s
# processing FIRENET/train/image312.jpg
# processing FIRENET/train/image313.jpg
# processing FIRENET/train/image314.jpg
# processing FIRENET/train/image315.jpg
# processing FIRENET/train/image316.jpg
# processing FIRENET/train/image317.jpg
# processing FIRENET/train/image318.jpg
# processing FIRENET/train/image319.jpg
# processing FIRENET/train/image320.jpg
# processing FIRENET/train/image321.jpg
# Processed 320 images... Average inference time so far: 1.878s
# processing FIRENET/train/image322.jpg
# processing FIRENET/train/image323.jpg
# processing FIRENET/train/image324.jpg
# processing FIRENET/train/image325.jpg
# processing FIRENET/train/image326.jpg
# processing FIRENET/train/image327.jpg
# processing FIRENET/train/image328.jpg
# processing FIRENET/train/image329.jpg
# processing FIRENET/train/image330.jpg
# processing FIRENET/train/image331.jpg
# Processed 330 images... Average inference time so far: 1.873s
# processing FIRENET/train/image332.jpg
# processing FIRENET/train/image333.jpg
# processing FIRENET/train/image334.jpg
# processing FIRENET/train/image335.jpg
# processing FIRENET/train/image336.jpg
# processing FIRENET/train/image337.jpg
# processing FIRENET/train/image338.jpg
# processing FIRENET/train/image339.jpg
# processing FIRENET/train/image340.jpg
# processing FIRENET/train/image341.jpg
# Processed 340 images... Average inference time so far: 1.872s
# processing FIRENET/train/image342.jpg
# processing FIRENET/train/image343.jpg
# processing FIRENET/train/image344.jpg
# processing FIRENET/train/image345.jpg
# processing FIRENET/train/image346.jpg
# processing FIRENET/train/image347.jpg
# processing FIRENET/train/image348.jpg
# processing FIRENET/train/image349.jpg
# processing FIRENET/train/image350.jpg
# processing FIRENET/train/image351.jpg
# Processed 350 images... Average inference time so far: 1.869s
# processing FIRENET/train/image352.jpg
# processing FIRENET/train/image353.jpg
# processing FIRENET/train/image354.jpg
# processing FIRENET/train/image355.jpg
# processing FIRENET/train/image356.jpg
# processing FIRENET/train/image357.jpg
# processing FIRENET/train/image358.jpg
# processing FIRENET/train/image359.jpg
# processing FIRENET/train/image360.jpg
# processing FIRENET/train/image361.jpg
# Processed 360 images... Average inference time so far: 1.873s
# processing FIRENET/train/image362.jpg
# processing FIRENET/train/image363.jpg
# processing FIRENET/train/image364.jpg
# processing FIRENET/train/image365.jpg
# processing FIRENET/train/image366.jpg
# processing FIRENET/train/image367.jpg
# processing FIRENET/train/image368.jpg
# processing FIRENET/train/image369.jpg
# processing FIRENET/train/image370.jpg
# processing FIRENET/train/image371.jpg
# Processed 370 images... Average inference time so far: 1.873s
# processing FIRENET/train/image372.jpg
# processing FIRENET/train/image373.jpg
# processing FIRENET/train/image374.jpg
# processing FIRENET/train/image375.jpg
# processing FIRENET/train/image376.jpg
# processing FIRENET/train/image377.jpg
# processing FIRENET/train/image378.jpg
# processing FIRENET/train/image379.jpg
# processing FIRENET/train/image380.jpg
# processing FIRENET/train/image381.jpg
# Processed 380 images... Average inference time so far: 1.867s
# processing FIRENET/train/image382.jpg
# processing FIRENET/train/image383.jpg
# processing FIRENET/train/image384.jpg
# processing FIRENET/train/image385.jpg
# processing FIRENET/train/image386.jpg
# processing FIRENET/train/image387.jpg
# processing FIRENET/train/image388.jpg
# processing FIRENET/train/image389.jpg
# processing FIRENET/train/image390.jpg
# processing FIRENET/train/image391.jpg
# Processed 390 images... Average inference time so far: 1.864s
# processing FIRENET/train/image392.jpg
# processing FIRENET/train/image393.jpg
# processing FIRENET/train/image394.jpg
# processing FIRENET/train/image395.jpg
# processing FIRENET/train/image396.jpg
# processing FIRENET/train/image397.jpg
# processing FIRENET/train/image398.jpg
# processing FIRENET/train/image399.jpg
# processing FIRENET/train/image400.jpg
# processing FIRENET/train/image401.jpg
# Processed 400 images... Average inference time so far: 1.865s
# processing FIRENET/train/image402.jpg
# processing FIRENET/train/image403.jpg
# processing FIRENET/train/image404.jpg
# processing FIRENET/train/image405.jpg
# processing FIRENET/train/image406.jpg
# processing FIRENET/train/image407.jpg
# processing FIRENET/train/image408.jpg
# processing FIRENET/train/image409.jpg
# processing FIRENET/train/image410.jpg
# processing FIRENET/train/image411.jpg
# Processed 410 images... Average inference time so far: 1.863s
# processing FIRENET/train/image412.jpg
# processing FIRENET/validation/image1.jpg
# processing FIRENET/validation/image2.jpg
# processing FIRENET/validation/image3.jpg
# processing FIRENET/validation/image4.jpg
# processing FIRENET/validation/image5.jpg
# processing FIRENET/validation/image6.jpg
# processing FIRENET/validation/image7.jpg
# processing FIRENET/validation/image8.jpg
# processing FIRENET/validation/image9.jpg
# Processed 420 images... Average inference time so far: 1.862s
# processing FIRENET/validation/image10.jpg
# processing FIRENET/validation/image11.jpg
# processing FIRENET/validation/image12.jpg
# processing FIRENET/validation/image13.jpg
# processing FIRENET/validation/image14.jpg
# processing FIRENET/validation/image15.jpg
# processing FIRENET/validation/image16.jpg
# processing FIRENET/validation/image17.jpg
# processing FIRENET/validation/image18.jpg
# processing FIRENET/validation/image19.jpg
# Processed 430 images... Average inference time so far: 1.864s
# processing FIRENET/validation/image20.jpg
# processing FIRENET/validation/image21.jpg
# processing FIRENET/validation/image22.jpg
# processing FIRENET/validation/image23.jpg
# processing FIRENET/validation/image24.jpg
# processing FIRENET/validation/image25.jpg
# processing FIRENET/validation/image26.jpg
# processing FIRENET/validation/image27.jpg
# processing FIRENET/validation/image28.jpg
# processing FIRENET/validation/image29.jpg
# Processed 440 images... Average inference time so far: 1.866s
# processing FIRENET/validation/image30.jpg
# processing FIRENET/validation/image31.jpg
# processing FIRENET/validation/image32.jpg
# processing FIRENET/validation/image33.jpg
# processing FIRENET/validation/image34.jpg
# processing FIRENET/validation/image35.jpg
# processing FIRENET/validation/image36.jpg
# processing FIRENET/validation/image37.jpg
# processing FIRENET/validation/image38.jpg
# processing FIRENET/validation/image39.jpg
# Processed 450 images... Average inference time so far: 1.866s
# processing FIRENET/validation/image40.jpg
# processing FIRENET/validation/image41.jpg
# processing FIRENET/validation/image42.jpg
# processing FIRENET/validation/image43.jpg
# processing FIRENET/validation/image44.jpg
# processing FIRENET/validation/image45.jpg
# processing FIRENET/validation/image46.jpg
# processing FIRENET/validation/image47.jpg
# processing FIRENET/validation/image48.jpg
# processing FIRENET/validation/image49.jpg
# Processed 460 images... Average inference time so far: 1.862s
# processing FIRENET/validation/image50.jpg
# processing FIRENET/validation/image51.jpg
# processing FIRENET/validation/image52.jpg
# processing FIRENET/validation/image53.jpg
# processing FIRENET/validation/image54.jpg
# processing FIRENET/validation/image55.jpg
# processing FIRENET/validation/image56.jpg
# processing FIRENET/validation/image57.jpg
# processing FIRENET/validation/image58.jpg
# processing FIRENET/validation/image59.jpg
# Processed 470 images... Average inference time so far: 1.865s
# processing FIRENET/validation/image60.jpg
# processing FIRENET/validation/image61.jpg
# processing FIRENET/validation/image62.jpg
# processing FIRENET/validation/image63.jpg
# processing FIRENET/validation/image64.jpg
# processing FIRENET/validation/image65.jpg
# processing FIRENET/validation/image66.jpg
# processing FIRENET/validation/image67.jpg
# processing FIRENET/validation/image68.jpg
# processing FIRENET/validation/image69.jpg
# Processed 480 images... Average inference time so far: 1.865s
# processing FIRENET/validation/image70.jpg
# processing FIRENET/validation/image71.jpg
# processing FIRENET/validation/image72.jpg
# processing FIRENET/validation/image73.jpg
# processing FIRENET/validation/image74.jpg
# processing FIRENET/validation/image75.jpg
# processing FIRENET/validation/image76.jpg
# processing FIRENET/validation/image77.jpg
# processing FIRENET/validation/image78.jpg
# processing FIRENET/validation/image79.jpg
# Processed 490 images... Average inference time so far: 1.864s
# processing FIRENET/validation/image80.jpg
# processing FIRENET/validation/image81.jpg
# processing FIRENET/validation/image82.jpg
# processing FIRENET/validation/image83.jpg
# processing FIRENET/validation/image84.jpg
# processing FIRENET/validation/image85.jpg
# processing FIRENET/validation/image86.jpg
# processing FIRENET/validation/image87.jpg
# processing FIRENET/validation/image88.jpg
# processing FIRENET/validation/image89.jpg
# Processed 500 images... Average inference time so far: 1.867s
# processing FIRENET/validation/image90.jpg
#
# Processing complete! Average inference time: 1.867s

# %%
# Save results to CSV
results_df = pd.DataFrame({
    'image_path': df['image_path'],
    'true_label': ground_truth,
    'predicted_label': predictions,
    'caption': captions,
    'inference_time': inference_times,
    'correct': [t == p for t, p in zip(ground_truth, predictions)]
})

results_df.to_csv('internvl3_2B_FINE_TUNED_results.csv', index=False)
print("Results saved to internvl3_2B_FINE_TUNED_results.csv")
# Out:
# Results saved to internvl3_2B_FINE_TUNED_results.csv

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

# Load the CSV file
df = pd.read_csv("internvl3_2B_FINE_TUNED_results.csv")
df = df.dropna(subset=['true_label', 'predicted_label', 'inference_time'])  # Remove rows with missing values

# Extract relevant columns
ground_truth = df['true_label'].astype(str).str.strip()
predictions = df['predicted_label'].astype(str).str.strip()
inference_times = df['inference_time'].astype(float)

# Calculate classification metrics
accuracy = accuracy_score(ground_truth, predictions)
precision, recall, f1, _ = precision_recall_fscore_support(
    ground_truth, predictions, average='weighted'
)

# Print performance metrics
print("Model Performance Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Inference time stats
print("\nInference Time Statistics:")
print(f"Average: {np.mean(inference_times):.3f}s")
print(f"Std Dev: {np.std(inference_times):.3f}s")
print(f"Min: {np.min(inference_times):.3f}s")
print(f"Max: {np.max(inference_times):.3f}s")
# Out:
# Model Performance Metrics:
# Accuracy: 0.8068
# Precision: 0.9921
# Recall: 0.8068
# F1 Score: 0.8617
#
# Inference Time Statistics:
# Average: 1.867s
# Std Dev: 0.374s
# Min: 0.999s
# Max: 3.250s

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion matrix
labels = sorted(df['true_label'].unique())
cm = confusion_matrix(ground_truth, predictions, labels=labels)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=labels,
    yticklabels=labels
)
plt.title('Confusion Matrix for internvl3_2B_FINE_TUNED')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
