# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook is used to:
# - See distribution of each labels: no fire, dangerous fire, controlled fire
# - to be decided ...

# %%
import pandas as pd
df1 = pd.read_csv("train_labels.csv")
df2 = pd.read_csv("val_labels.csv")
df3 = pd.read_csv("test_labels.csv")
df = pd.concat([df1,df2,df3])
df
# Out:
#                                        image_path            label  \
# 0      fine_tune_dataset/train/images/train_1.jpg  controlled fire
# 1      fine_tune_dataset/train/images/train_2.jpg          no fire
# 2      fine_tune_dataset/train/images/train_3.jpg          no fire
# 3      fine_tune_dataset/train/images/train_4.jpg  controlled fire
# 4      fine_tune_dataset/train/images/train_5.jpg  controlled fire
# ...                                           ...              ...
# 1285  fine_tune_dataset/test/images/test_1296.jpg          no fire
# 1286  fine_tune_dataset/test/images/test_1297.jpg  controlled fire
# 1287  fine_tune_dataset/test/images/test_1298.jpg  controlled fire
# 1288  fine_tune_dataset/test/images/test_1299.jpg  controlled fire
# 1289  fine_tune_dataset/test/images/test_1300.jpg          no fire
#
#                                                 caption
# 0     The image shows a computer setup on a desk wit...
# ...

# %%
label_counts = df['label'].value_counts()
print("Label Distribution:")
print(label_counts)
# Out:
# Label Distribution:
# label
# controlled fire    3546
# no fire            1976
# dangerous fire      960
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

label_counts = df['label'].value_counts()
labels = label_counts.index
counts = label_counts.values
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# --- Bar chart ---
bars = ax1.bar(labels, counts, color=['green', 'red', 'orange'])
ax1.set_title('Label Distribution (Bar Chart)')
ax1.set_xlabel('Labels')
ax1.set_ylabel('Number of Images')
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Add exact counts on top of each bar
for bar in bars:
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height + 1, f'{int(height)}',
             ha='center', va='bottom', fontsize=10)

# --- Pie chart ---
ax2.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=['lightgreen', 'tomato', 'gold'],
        wedgeprops={'edgecolor': 'black'})
ax2.set_title('Label Proportion (Pie Chart)')

# Tidy layout
plt.tight_layout()
plt.show()
