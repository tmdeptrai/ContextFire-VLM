# %%
model_path = 'OpenGVLab/InternVL3-1B'
INPUT_CSV = '../labels_v2.csv'
OUTPUT_CSV = 'internvl3_1B_results.csv'

# %%
import pandas as pd
# Load ground truth data
df = pd.read_csv(INPUT_CSV)
print(f"Total samples in dataset: {len(df)}")
df.head()
# Out:
# Total samples in dataset: 452
#               image_path    label  \
# 0  dataset_v2/image1.jpg  no fire
# 1  dataset_v2/image2.jpg  no fire
# 2  dataset_v2/image3.jpg  no fire
# 3  dataset_v2/image4.jpg  no fire
# 4  dataset_v2/image5.jpg  no fire
#
#                                              caption
# 0  The image shows a cozy living room with a fire...
# 1  The image shows a neatly arranged bedroom with...
# 2  The image shows a dining area with a wooden ta...
# 3  The image shows a modern office space with lar...
# 4  The image shows a hospital room with a patient...

# %%
import math
import numpy as np
import torch
import torchvision.transforms as T
from decord import VideoReader, cpu
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer, AutoConfig
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import time, re, json
import os

# %%
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)

def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([
        T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
        T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
        T.ToTensor(),
        T.Normalize(mean=MEAN, std=STD)
    ])
    return transform

def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float('inf')
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio

def dynamic_preprocess(image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set(
        (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
        i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(
        aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = (
            (i % (target_width // image_size)) * image_size,
            (i // (target_width // image_size)) * image_size,
            ((i % (target_width // image_size)) + 1) * image_size,
            ((i // (target_width // image_size)) + 1) * image_size
        )
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images

def load_image(image_file, input_size=448, max_num=12):
    image = Image.open(image_file).convert('RGB')
    transform = build_transform(input_size=input_size)
    images = dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
    pixel_values = [transform(image) for image in images]
    pixel_values = torch.stack(pixel_values)
    return pixel_values

def split_model(model_name):
    device_map = {}
    world_size = torch.cuda.device_count()
    config = AutoConfig.from_pretrained(model_path, trust_remote_code=True)
    num_layers = config.llm_config.num_hidden_layers
    # Since the first GPU will be used for ViT, treat it as half a GPU.
    num_layers_per_gpu = math.ceil(num_layers / (world_size - 0.5))
    num_layers_per_gpu = [num_layers_per_gpu] * world_size
    num_layers_per_gpu[0] = math.ceil(num_layers_per_gpu[0] * 0.5)
    layer_cnt = 0
    for i, num_layer in enumerate(num_layers_per_gpu):
        for j in range(num_layer):
            device_map[f'language_model.model.layers.{layer_cnt}'] = i
            layer_cnt += 1
    device_map['vision_model'] = 0
    device_map['mlp1'] = 0
    device_map['language_model.model.tok_embeddings'] = 0
    device_map['language_model.model.embed_tokens'] = 0
    device_map['language_model.output'] = 0
    device_map['language_model.model.norm'] = 0
    device_map['language_model.model.rotary_emb'] = 0
    device_map['language_model.lm_head'] = 0
    device_map[f'language_model.model.layers.{num_layers - 1}'] = 0

    return device_map

# %%
# If you set `load_in_8bit=True`, you will need two 80GB GPUs.
# If you set `load_in_8bit=False`, you will need at least three 80GB GPUs.
device_map = split_model('InternVL3-1B')
model = AutoModel.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
    load_in_8bit=False,
    trust_remote_code=True,
    device_map="cuda").eval()
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True, use_fast=False)
print("Sucessfully loaded the model")
# Out:
# FlashAttention2 is not installed.
# Sucessfully loaded the model

# %%
# generation_config = dict(max_new_tokens=2048, do_sample=True, pad_token_id=tokenizer.eos_token_id)
# def process_image(image_path):
#     """Process a single image and return the model's prediction, caption and inference time"""
#     try:
#         # Start timing
#         start_time = time.time()
        
#         # set the max number of tiles in `max_num`
#         pixel_values = load_image(image_path, max_num=12).to(torch.bfloat16).cuda()
#         prompt = (
#             "\nYou are a visual analyst evaluating an image for signs of fire and the surrounding context. "
#             "Do the following tasks:\n"
#             "1: Summarize what you see in the image. Describe the environment, key objects, people, and any signs of fire or smoke.\n"
#             "2: Based on your summary, classify the fire situation: "
#             "no fire(e.g., fire alarm, fire distinguisher, fireplace with no fire burning inside..), controlled fire (e.g., fireplace with a fire burning inside, campfire, cooking, candles, match stick, lighter..) or a dangerous/uncontrolled fire (e.g., curtains on fire, smoke on ceiling, couch on fire, bed sheet on fire, spreading fire on furniture..)?\n"
#             "Return only this JSON format:\n"
#             "{ \"caption\": \"...\", \"label\": \"no fire\"|\"controlled fire\"|\"dangerous fire\" }"
#         )
#         response = model.chat(tokenizer, pixel_values, prompt, generation_config)
        
        
#         # Match the last complete JSON block
#         matches = re.findall(r'\{[^{}]+\}', response, re.DOTALL)
#         if matches:
#             try:
#                 result = json.loads(matches[-1])  # take the last match (most likely correct)
#                 caption = result.get("caption", "").strip()
#                 label = result.get("label", "").strip()
#             except Exception as e:
#                 print(f"❌ Failed to parse JSON for {image_path}: {e}")
#                 print(response)
#                 caption = response
#                 label = "unknown"
#         else:
#             print(f"❌ No JSON block found in output for {image_path}")
#             caption = response
#             label = "unknown"

#         # Calculate inference time
#         inference_time = time.time() - start_time
        
#         return label, caption, inference_time
            
#     except Exception as e:
#         print(f"Error processing {image_path}: {str(e)}")
#         return "error", "", 0.0

from lmdeploy import pipeline, TurbomindEngineConfig, ChatTemplateConfig
from lmdeploy.vl import load_image

model = 'OpenGVLab/InternVL3-1B'
pipe = pipeline(model, backend_config=TurbomindEngineConfig(session_len=16384, tp=1), chat_template_config=ChatTemplateConfig(model_name='internvl2_5'))

def process_image(image_path):
    """Process a single image and return the model's prediction, caption and inference time"""
    try:
        # Start timing
        start_time = time.time()
        
        image = load_image(image_path)
        
        prompt = (
            "\nYou are a visual analyst evaluating an image for signs of fire and the surrounding context. "
            "Do the following tasks:\n"
            "1: Summarize what you see in the image. Describe the environment, key objects, people, and any signs of fire or smoke.\n"
            "2: Based on your summary, classify the fire situation: "
            "no fire(e.g., fire alarm, fire distinguisher, fireplace with no fire burning inside..), controlled fire (e.g., fireplace with a fire burning inside, campfire, cooking, candles, match stick, lighter..) or a dangerous/uncontrolled fire (e.g., curtains on fire, smoke on ceiling, couch on fire, bed sheet on fire, spreading fire on furniture..)?\n"
            "Return only this JSON format:\n"
            "{ \"caption\": \"...\", \"label\": \"no fire\"|\"controlled fire\"|\"dangerous fire\" }"
        )
        
        response = pipe((prompt, image))
        response = response.text
            
        # Match the last complete JSON block
        matches = re.findall(r'\{[^{}]+\}', response, re.DOTALL)
        if matches:
            try:
                result = json.loads(matches[-1])  # take the last match (most likely correct)
                caption = result.get("caption", "").strip()
                label = result.get("label", "").strip()
            except Exception as e:
                print(f"❌ Failed to parse JSON for {image_path}: {e}")
                print(response)
                caption = response
                label = "unknown"
        else:
            print(f"❌ No JSON block found in output for {image_path}")
            caption = response
            label = "unknown"

        # Calculate inference time
        inference_time = time.time() - start_time
        
        return label, caption, inference_time
            
    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        return "error", "", 0.0
# Out:
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# FlashAttention2 is not installed.
# 2025-07-11 03:32:13,749 - lmdeploy - WARNING - turbomind.py:286 - get 219 model params
# [TM][WARNING] [LlamaTritonModel] `max_context_token_num` is not set, default to 16384.
# 2025-07-11 03:32:14,674 - lmdeploy - WARNING - tokenizer.py:499 - The token <|action_end|>, its length of indexes [27, 91, 1311, 6213, 91, 29] is over than 1. Currently, it can not be used as stop words

# %%
import os
# Process all images and collect predictions
predictions = []
captions = []
inference_times = []
ground_truth = []

for idx, row in df.iterrows():
    img_path = os.path.join('../', row['image_path'])
    if os.path.exists(img_path):
        pred, caption, inf_time = process_image(img_path)
        predictions.append(pred)
        captions.append(caption)
        inference_times.append(inf_time)
        ground_truth.append(row['label'])
        if idx % 10 == 0:
            print(f"Processed {idx} images... Average inference time so far: {np.mean(inference_times):.3f}s")

print(f"\nProcessing complete! Average inference time: {np.mean(inference_times):.3f}s")
# Out:
# 2025-07-11 03:32:42,148 - lmdeploy - WARNING - async_engine.py:657 - GenerationConfig: GenerationConfig(n=1, max_new_tokens=512, do_sample=False, top_p=1.0, top_k=50, min_p=0.0, temperature=0.8, repetition_penalty=1.0, ignore_eos=False, random_seed=None, stop_words=None, bad_words=None, stop_token_ids=[151645], bad_token_ids=None, min_new_tokens=None, skip_special_tokens=True, spaces_between_special_tokens=True, logprobs=None, response_format=None, logits_processors=None, output_logits=None, output_last_hidden_state=None, with_cache=False, preserve_cache=False, migration_request=None)
# 2025-07-11 03:32:42,150 - lmdeploy - WARNING - async_engine.py:658 - Since v0.6.0, lmdeploy add `do_sample` in GenerationConfig. It defaults to False, meaning greedy decoding. Please set `do_sample=True` if sampling  decoding is needed
# Processed 0 images... Average inference time so far: 0.542s
# ❌ Failed to parse JSON for ../dataset_v2/image5.jpg: Expecting ',' delimiter: line 3 column 3 (char 396)
# ```json
# {
#   "caption": "The image shows a hospital room with a hospital bed covered in white sheets, a medical table with a tray of food, and curtains in the background. There is a medical stand with various items, including bottles and a bag. The room appears to be well-lit with a window and an air conditioner visible. There are no visible signs of fire or smoke, and the environment seems normal."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image10.jpg: Expecting ',' delimiter: line 3 column 3 (char 261)
# ```json
# {
#   "caption": "The image shows a modern office with a large desk, a laptop, and a chair. There is a bed with pillows in the background, and large windows letting in natural light. The room appears well-lit and clean, with no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 10 images... Average inference time so far: 0.250s
# ❌ Failed to parse JSON for ../dataset_v2/image12.jpg: Expecting ',' delimiter: line 3 column 3 (char 335)
# ```json
# {
#   "caption": "The image shows a hospital room with a hospital bed covered in a white sheet with a blue and pink pattern. There is a table in front of the bed, and curtains are partially drawn. The room has a patterned wallpaper and a lamp on a shelf. There are no visible signs of fire or smoke, and the environment appears calm."
#   "label": "no fire"
# }
# ```
# Processed 20 images... Average inference time so far: 0.238s
# ❌ Failed to parse JSON for ../dataset_v2/image23.jpg: Expecting ',' delimiter: line 3 column 3 (char 276)
# ```json
# {
#   "caption": "The image shows a well-organized wooden desk setup with a computer, printer, and various books and binders. There is a chair, a basket, and a framed picture on the desk. The room appears tidy and functional, but there are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 30 images... Average inference time so far: 0.231s
# Processed 40 images... Average inference time so far: 0.226s
# Processed 50 images... Average inference time so far: 0.222s
# ❌ Failed to parse JSON for ../dataset_v2/image54.jpg: Expecting ',' delimiter: line 3 column 3 (char 247)
# ```json
# {
#   "caption": "The image shows a cozy bedroom with a bed covered in a colorful quilt. There is a wooden chair and a bedside table with a lamp in the background. The room appears to be well-lit, and there are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 60 images... Average inference time so far: 0.222s
# Processed 70 images... Average inference time so far: 0.220s
# ❌ Failed to parse JSON for ../dataset_v2/image74.jpg: Expecting ',' delimiter: line 3 column 3 (char 262)
# ```json
# {
#   "caption": "The image shows a modern home office with a desk, chair, and bookshelves. There is a window with a view of the outside, and a lamp is visible on the desk. The room appears clean and well-organized. There are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 80 images... Average inference time so far: 0.219s
# ❌ Failed to parse JSON for ../dataset_v2/image91.jpg: Expecting ',' delimiter: line 3 column 3 (char 303)
# ```json
# {
#   "caption": "The image shows a well-lit bedroom with a large bed, a green armchair, and a nightstand with various items including books and a framed photo. Curtains are partially drawn, and there is a lamp on the nightstand. The room appears tidy and calm, with no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 90 images... Average inference time so far: 0.219s
# Processed 100 images... Average inference time so far: 0.220s
# Processed 110 images... Average inference time so far: 0.219s
# Processed 120 images... Average inference time so far: 0.219s
# ❌ Failed to parse JSON for ../dataset_v2/image122.jpg: Expecting ',' delimiter: line 3 column 3 (char 319)
# ```json
# {
#   "caption": "The image shows a dining room with a round wooden table surrounded by chairs, a lace tablecloth, and a decorative centerpiece. The room has a warm, homey feel with framed pictures on the walls and a wooden cabinet. There are no visible signs of fire or smoke, and the environment appears to be safe."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image124.jpg: Expecting ',' delimiter: line 3 column 3 (char 275)
# ```json
# {
#   "caption": "The image shows a well-appointed office with a wooden desk, two upholstered chairs, and a globe on the desk. There are cabinets above the desk, a plant, and a window with blinds. The room appears tidy and organized, with no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image130.jpg: Expecting ',' delimiter: line 3 column 3 (char 297)
# ```json
# {
#   "caption": "The image shows a traditional Japanese room with a wooden table, two teacups, and a hanging pendant light. There is a window with sliding shoji screens, allowing natural light to enter. Outside, a garden with trees and a fence is visible. No signs of fire or smoke are present."
#   "label": "no fire"
# }
# ```
# Processed 130 images... Average inference time so far: 0.219s
# Processed 140 images... Average inference time so far: 0.217s
# Processed 150 images... Average inference time so far: 0.216s
# ❌ Failed to parse JSON for ../dataset_v2/image161.jpg: Expecting ',' delimiter: line 3 column 3 (char 324)
# ```json
# {
#   "caption": "The image shows a living room with a fireplace, a glass coffee table, and two armchairs. There is a lamp on the left side of the room, and a fireplace with a visible fire burning inside. The room has a patterned area rug, and there are framed pictures on the walls. No signs of fire or smoke are visible."
#   "label": "no fire"
# }
# ```
# Processed 160 images... Average inference time so far: 0.215s
# ❌ Failed to parse JSON for ../dataset_v2/image162.jpg: Expecting ',' delimiter: line 3 column 3 (char 345)
# ```json
# {
#   "caption": "The image shows a lavishly decorated bedroom with a large bed, ornate headboard, and two matching nightstands. There are chairs with blue upholstery around the bed. The room has a soft pink wall color and a patterned rug. There are no visible signs of fire, smoke, or flames, indicating a controlled fire or safe environment."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image164.jpg: Expecting ',' delimiter: line 3 column 3 (char 296)
# ```json
# {
#   "caption": "The image shows a living room with a wooden table, chairs, and a patterned rug. There is a television on a wooden stand, a lamp on the table, and a bed with a floral bedspread in the background. The room appears to be well-lit and tidy, with no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 170 images... Average inference time so far: 0.215s
# Processed 180 images... Average inference time so far: 0.215s
# ❌ Failed to parse JSON for ../dataset_v2/image190.jpg: Expecting ',' delimiter: line 3 column 3 (char 332)
# ```json
# {
#   "caption": "The image shows a living room with a television on a stand, a sofa with pillows, and a coffee table. There is a window with a white refrigerator beside it. The room appears to be well-lit with natural light coming through the window. There are no visible signs of fire or smoke, and the environment looks normal."
#   "label": "no fire"
# }
# ```
# Processed 190 images... Average inference time so far: 0.214s
# Processed 200 images... Average inference time so far: 0.214s
# Processed 210 images... Average inference time so far: 0.213s
# Processed 220 images... Average inference time so far: 0.212s
# ❌ Failed to parse JSON for ../dataset_v2/image222.jpg: Expecting ',' delimiter: line 3 column 3 (char 330)
# ```json
# {
#   "caption": "The image shows a well-lit dining room with a glass table set for a meal, surrounded by cream-colored chairs. Curtains are drawn to the sides, and there are decorative elements like a lamp and a framed picture on the wall. The room appears tidy and comfortable, but there are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image225.jpg: Expecting ',' delimiter: line 3 column 3 (char 305)
# ```json
# {
#   "caption": "The image shows a hotel room with two beds covered in plaid bedspreads, a wooden dresser with a lamp, a television, and a refrigerator. There is a framed picture on the wall and a curtain on the window. The room appears to be quiet and well-lit, with no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# ❌ Failed to parse JSON for ../dataset_v2/image227.jpg: Expecting ',' delimiter: line 3 column 3 (char 290)
# ```json
# {
#   "caption": "The image shows a bedroom with two beds, one with a floral bedspread and the other with a patterned bedspread. There is a mirror on the wall, a bedside table with a lamp, and a telephone. The room has blue walls and a window. There are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 230 images... Average inference time so far: 0.212s
# Processed 240 images... Average inference time so far: 0.211s
# Processed 250 images... Average inference time so far: 0.211s
# ❌ Failed to parse JSON for ../dataset_v2/image253.jpg: Expecting ',' delimiter: line 3 column 3 (char 314)
# ```json
# {
#   "caption": "The image shows a living room with a modern setup, including a television, a sofa with colorful cushions, and a yellow stool. There is a sliding glass door leading to a garden outside. The room is well-lit with a circular ceiling light and curtains. There are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 260 images... Average inference time so far: 0.211s
# Processed 270 images... Average inference time so far: 0.211s
# Processed 280 images... Average inference time so far: 0.210s
# Processed 290 images... Average inference time so far: 0.210s
# Processed 300 images... Average inference time so far: 0.211s
# Processed 310 images... Average inference time so far: 0.214s
# Processed 320 images... Average inference time so far: 0.219s
# ❌ Failed to parse JSON for ../dataset_v2/image1278.jpg: Expecting ',' delimiter: line 3 column 3 (char 229)
# ```json
# {
#   "caption": "The image depicts a vibrant painting of a fire with flames and smoke, set against a wall with a golden frame. The surrounding environment appears to be indoors, and there are no visible signs of fire or smoke."
#   "label": "no fire"
# }
# ```
# Processed 330 images... Average inference time so far: 0.225s
# Processed 340 images... Average inference time so far: 0.228s
# Processed 350 images... Average inference time so far: 0.234s
# Processed 360 images... Average inference time so far: 0.240s
# Processed 370 images... Average inference time so far: 0.245s
# Processed 380 images... Average inference time so far: 0.248s
# Processed 390 images... Average inference time so far: 0.252s
# ❌ Failed to parse JSON for ../dataset_v2/image1375.jpg: Expecting ',' delimiter: line 3 column 3 (char 332)
# ```json
# {
#   "caption": "A woman is sitting at a table with a fire burning in a circular metal grate, surrounded by bottles of wine and a tray with macarons and cheese. The scene is dimly lit, suggesting it is nighttime, and there is a relaxed atmosphere with other people in the background. No fire is visible in the immediate vicinity."
#   "label": "no fire"
# }
# ```
# Processed 400 images... Average inference time so far: 0.255s
# Processed 410 images... Average inference time so far: 0.260s
# Processed 420 images... Average inference time so far: 0.264s
# Processed 430 images... Average inference time so far: 0.266s
# Processed 440 images... Average inference time so far: 0.270s
# Processed 450 images... Average inference time so far: 0.274s
#
# Processing complete! Average inference time: 0.275s

# %%
# Save results to CSV
results_df = pd.DataFrame({
    'image_path': df['image_path'],
    'true_label': ground_truth,
    'predicted_label': predictions,
    'caption': captions,
    'inference_time': inference_times,
    'correct': [t == p for t, p in zip(ground_truth, predictions)]
})

results_df.to_csv(OUTPUT_CSV, index=False)
print(f"Results saved to {OUTPUT_CSV}")
# Out:
# Results saved to internvl3_1B_results.csv

# %%
# Load the CSV file
df = pd.read_csv(OUTPUT_CSV)
df = df.dropna(subset=['true_label', 'predicted_label', 'inference_time'])  # Remove rows with missing values

# Extract relevant columns
ground_truth = df['true_label'].astype(str).str.strip()
predictions = df['predicted_label'].astype(str).str.strip()
inference_times = df['inference_time'].astype(float)

# Calculate classification metrics
accuracy = accuracy_score(ground_truth, predictions)
precision, recall, f1, _ = precision_recall_fscore_support(
    ground_truth, predictions, average='weighted'
)

# Print performance metrics
print("Model Performance Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Inference time stats
print("\nInference Time Statistics:")
print(f"Average: {np.mean(inference_times):.3f}s")
print(f"Std Dev: {np.std(inference_times):.3f}s")
print(f"Min: {np.min(inference_times):.3f}s")
print(f"Max: {np.max(inference_times):.3f}s")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Load the CSV file
# ----> 2 df = pd.read_csv(OUTPUT_CSV)
#       3 df = df.dropna(subset=['true_label', 'predicted_label', 'inference_time'])  # Remove rows with missing values
#       5 # Extract relevant columns
#
# NameError: name 'pd' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion matrix
labels = sorted(df['true_label'].unique())
cm = confusion_matrix(ground_truth, predictions, labels=labels)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=labels,
    yticklabels=labels
)
plt.title(f'Confusion Matrix for {model_path}')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
